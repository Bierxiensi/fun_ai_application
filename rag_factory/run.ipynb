# %%
from IntentAgent import IntentAgent

if __name__ == "__main__":
    agent = IntentAgent()
    # user_input = "客户经理被投诉了，投诉一次扣多少分"
    # file_path = 'data/浦发上海浦东发展银行西安分行个金客户经理考核办法.pdf'
    # user_input = "迪士尼有几个园区"
    # file_path = 'data/迪士尼乐园 _园区地图、各主题区域介绍.docx'
    user_input = "迪士尼各个园区有什么项目？"
    file_path = 'data/迪士尼乐园项目.xlsx'
    result = agent.run(user_input, file_path) 
    print(result)
# Out:
# {'query_type': 'rag_query', 'intent': '用户在询问迪士尼各个园区的具体项目内容，需要根据本地资料回答。', 'confidence': 0.95, 'reason': '用户明确询问迪士尼园区的项目信息，属于具体知识点查询。'}
# 文件 data/迪士尼乐园项目.xlsx 已处理过，跳过
# 迪士尼各个园区的项目根据所在地区有所不同，以下是主要迪士尼乐园的主题区域和代表性项目：
#
# ### 1. **迪士尼世界（佛罗里达州）**
# - **魔法王国公园（Magic Kingdom Park）**：标志性城堡、经典游乐设施如“小飞象”、“太空山”。
# - **迪士尼动物王国（Disney's Animal Kingdom）**：以自然和野生动物为主题，包含“潘多拉-阿凡达世界”、“泰山树屋”等。
# - **Epcot**：未来科技主题，有“星际旅行”等高科技项目。
# - **迪士尼好莱坞工作室（Disney's Hollywood Studios）**：电影主题，如“星战前传：绝地训练”。
# - **迪士尼暴风雪海滩（Disney's Blizzard Beach）**：冬季主题水上乐园，提供滑雪等冰雪活动。
#
# ### 2. **加州迪士尼乐园（加利福尼亚州）**
# - **迪士尼乐园（Disneyland Park）**：
#   - 米奇大街（Main Street, U.S.A.）：商店、餐厅和米奇标志性建筑。
#   - 幻想世界（Fantasyland）：经典童话项目如“小木偶奇遇记”、“白雪公主冒险旅程”。
#   - 边疆世界（Frontierland）：“大雷鸣山铁路”等西部风格项目。
#   - 冒险世界（Adventureland）：“丛林探险”等热带雨林项目。
#   - 新奥尔良广场（New Orleans Square）：法国风情建筑与音乐表演。
# - **迪士尼加州冒险乐园（Disney's California Adventure Park）**：
#   - 天堂码头（Paradise Pier）：海洋主题景点。
#   - 虫虫乐园（A Bug's Land）：昆虫主题家庭游玩区。
#   - 好莱坞电影幕后（Hollywood Pictures Backlot）：电影制作相关体验。
#
# ### 3. **巴黎迪士尼乐园（法国）**
# - **幻想世界（Fantasyland）**：如“小飞象”、“小木偶奇遇记”。
# - **边疆世界（Frontierland）**：西部风格建筑和“大雷鸣山铁路”。
# - **冒险世界（Adventureland）**：热带雨林景观和“丛林探险”。
# - **明日世界（Tomorrowland）**：现代科技气息，如“太空山”。
#
# ### 4. **东京迪士尼乐园（日本）**
# - **幻想世界（Fantasyland）**：如“小美人鱼”、“彼得潘之岛”。
# - **探险世界（Adventureland）**：丛林河流之旅和泰山树屋。
# - **明日世界（Tomorrowland）**：高科技互动项目。
# - **米奇卡通城（Mickey's Toontown）**：卡通风格适合家庭游玩。
# - **新奥尔良广场（New Orleans Square）**：法国风情建筑与音乐表演。
# - **发现世界（Discoveryland）**：未来科技主题项目。
# - **动物王国（Critter Country）**：小熊维尼历险记等动物主题项目。
#
# ### 5. **中国香港迪士尼乐园（中国香港）**
# - **幻想世界（Fantasyland）**：如“小美人鱼”、“彼得潘之岛”。
# - **探险世界（Adventureland）**：丛林河流之旅和泰山树屋。
# - **明日世界（Tomorrowland）**：高科技互动项目。
# - **米奇卡通城（Mickey's Toontown）**：卡通风格适合家庭游玩。
# - **新奥尔良广场（New Orleans Square）**：法国风情建筑与音乐表演。
# - **发现世界（Discoveryland）**：未来科技主题项目。
# - **动物王国（Critter Country）**：小熊维尼历险记等动物主题项目。
#
# ### 6. **上海迪士尼乐园（中国上海）**
# - **米奇大街**：入园后的第一个区域，有商店、餐厅和米奇标志性建筑。
# - **奇想花园**：美丽的花丛和奇幻喷泉，适合拍照留念。
# - **探险岛**：刺激过山车和热带风情。
# - **宝藏湾**：加勒比海盗主题，如海盗船和神秘洞穴。
# - **明日世界**：科幻与未来感十足，体验高科技互动项目。
# - **梦幻世界**：精致城堡和经典童话故事场景，适合亲子互动。
#
# 每个迪士尼乐园都通过独特的主题区域和项目，为游客提供沉浸式的奇幻体验。
