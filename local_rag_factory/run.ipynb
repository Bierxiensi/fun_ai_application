# %%
from IntentAgent import IntentAgent

if __name__ == "__main__":
    agent = IntentAgent()
    # user_input = "客户经理被投诉了，投诉一次扣多少分"
    # file_path = 'data/浦发上海浦东发展银行西安分行个金客户经理考核办法.pdf'
    user_input = "迪士尼有几个园区"
    file_path = 'data/迪士尼乐园 _园区地图、各主题区域介绍.docx'
    # user_input = "迪士尼各个园区有什么项目？"
    # file_path = 'data/迪士尼乐园项目.xlsx'
    result = agent.run(user_input, file_path) 
    print(result)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# 222 {
#     "query_type": "rag_query",
#     "intent": "询问迪士尼园区的数量",
#     "confidence": 0.98,
#     "reason": "用户在询问具体的知识点——迪士尼园区的数量，属于对事实性信息的查询。"
# }
# 111 {'query_type': 'rag_query', 'intent': '询问迪士尼园区的数量', 'confidence': 0.98, 'reason': '用户在询问具体的知识点——迪士尼园区的数量，属于对事实性信息的查询。'}
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# 成功添加文档 data/迪士尼乐园 _园区地图、各主题区域介绍.docx，共 8 个文本块
# 333 根据上下文信息，迪士尼乐园的园区数量和结构因地区而异。例如：
#
# - **上海迪士尼乐园**分为六个主要主题区：米奇大街、奇想花园、探险岛、宝藏湾、明日世界和梦幻世界。
# - **迪士尼世界（佛罗里达州）** 包含多个主题公园和酒店，主要区域包括魔法王国公园、迪士尼动物王国、Epcot、迪士尼暴风雪海滩、迪士尼好莱坞工作室和迪士尼码头。
# - **加州迪士尼乐园** 包括迪士尼乐园（Disneyland Park）和迪士尼加州冒险乐园（Disney's California Adventure Park），后者又分为天堂码头、虫虫乐园和好莱坞电影幕后等区域。
# - **东京迪士尼乐园** 分为七个主题区域，包括幻想世界、探险世界、明日世界、米奇卡通城、新奥尔良广场、发现世界和动物王国。
# - **巴黎迪士尼乐园** 分为五个主要部分，包括幻想世界、边疆世界、探险世界和明日世界。
# - **中国香港迪士尼乐园** 分为七个主题园区，包括幻想世界、探险世界、明日世界、米奇卡通城、新奥尔良广场、发现世界和动物王国。
#
# 因此，不同地区的迪士尼乐园园区数量和主题区域各不相同，通常在5到7个之间。
# 根据上下文信息，迪士尼乐园的园区数量和结构因地区而异。例如：
#
# - **上海迪士尼乐园**分为六个主要主题区：米奇大街、奇想花园、探险岛、宝藏湾、明日世界和梦幻世界。
# - **迪士尼世界（佛罗里达州）** 包含多个主题公园和酒店，主要区域包括魔法王国公园、迪士尼动物王国、Epcot、迪士尼暴风雪海滩、迪士尼好莱坞工作室和迪士尼码头。
# - **加州迪士尼乐园** 包括迪士尼乐园（Disneyland Park）和迪士尼加州冒险乐园（Disney's California Adventure Park），后者又分为天堂码头、虫虫乐园和好莱坞电影幕后等区域。
# - **东京迪士尼乐园** 分为七个主题区域，包括幻想世界、探险世界、明日世界、米奇卡通城、新奥尔良广场、发现世界和动物王国。
# - **巴黎迪士尼乐园** 分为五个主要部分，包括幻想世界、边疆世界、探险世界和明日世界。
# - **中国香港迪士尼乐园** 分为七个主题园区，包括幻想世界、探险世界、明日世界、米奇卡通城、新奥尔良广场、发现世界和动物王国。
#
# 因此，不同地区的迪士尼乐园园区数量和主题区域各不相同，通常在5到7个之间。

# %%
user_input = "迪士尼各个园区有什么项目？"
file_path = 'data/迪士尼乐园项目.xlsx'
result = agent.run(user_input, file_path) 
print(result)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
# 222 {
#     "query_type": "rag_query",
#     "intent": "查询迪士尼各个园区的项目内容",
#     "confidence": 0.98,
#     "reason": "用户明确询问迪士尼园区的具体项目，属于对具体知识点的查询，符合RAG查询意图。"
# }
# 111 {'query_type': 'rag_query', 'intent': '查询迪士尼各个园区的项目内容', 'confidence': 0.98, 'reason': '用户明确询问迪士尼园区的具体项目，属于对具体知识点的查询，符合RAG查询意图。'}
# data/迪士尼乐园项目.xlsx
# 成功添加文档 data/迪士尼乐园项目.xlsx，共 1 个文本块
# 333 迪士尼各个园区的项目如下：
#
# 1. **幻想世界（Fantasyland）**：
#    - 佛罗里达州迪士尼世界：有“小飞象”、“小木偶奇遇记”等经典项目。
#    - 巴黎迪士尼乐园：有“小飞象”、“小木偶奇遇记”等经典项目。
#    - 中国香港迪士尼乐园：有“小美人鱼”、“彼得潘之岛”等童话主题项目。
#    - 东京迪士尼乐园：有“小美人鱼”、“彼得潘之岛”等童话主题项目。
#    - 上海迪士尼乐园：有“梦幻世界”中的经典童话故事场景，适合亲子互动。
#
# 2. **边疆世界（Frontierland）**：
#    - 佛罗里达州迪士尼世界：有西部风格的建筑和“大雷鸣山铁路”等项目。
#    - 巴黎迪士尼乐园：有西部风格的建筑和“大雷鸣山铁路”等项目。
#    - 加州迪士尼乐园：有西部风格的建筑和“大雷鸣山铁路”等项目。
#
# 3. **探险世界（Adventureland）**：
#    - 佛罗里达州迪士尼世界：有热带雨林的景观和“丛林探险”等项目。
#    - 巴黎迪士尼乐园：有热带雨林的景观和“丛林探险”等项目。
#    - 中国香港迪士尼乐园：有丛林河流之旅和泰山树屋等冒险元素。
#    - 东京迪士尼乐园：有丛林河流之旅和泰山树屋等冒险元素。
#
# 4. **明日世界（Tomorrowland）**：
#    - 佛罗里达州迪士尼世界：有现代科技的气息，有“太空山”、“星际旅行”等高科技项目。
#    - 巴黎迪士尼乐园：有现代科技的气息，有“太空山”、“星际旅行”等高科技项目。
#    - 中国香港迪士尼乐园：有高科技互动项目。
#    - 东京迪士尼乐园：有高科技互动项目。
#    - 上海迪士尼乐园：有科幻与未来感十足的高科技互动项目。
#
# 5. **米奇卡通城（Mickey's Toontown）**：
#    - 中国香港迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#    - 东京迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#    - 加州迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#
# 6. **新奥尔良广场
# 迪士尼各个园区的项目如下：
#
# 1. **幻想世界（Fantasyland）**：
#    - 佛罗里达州迪士尼世界：有“小飞象”、“小木偶奇遇记”等经典项目。
#    - 巴黎迪士尼乐园：有“小飞象”、“小木偶奇遇记”等经典项目。
#    - 中国香港迪士尼乐园：有“小美人鱼”、“彼得潘之岛”等童话主题项目。
#    - 东京迪士尼乐园：有“小美人鱼”、“彼得潘之岛”等童话主题项目。
#    - 上海迪士尼乐园：有“梦幻世界”中的经典童话故事场景，适合亲子互动。
#
# 2. **边疆世界（Frontierland）**：
#    - 佛罗里达州迪士尼世界：有西部风格的建筑和“大雷鸣山铁路”等项目。
#    - 巴黎迪士尼乐园：有西部风格的建筑和“大雷鸣山铁路”等项目。
#    - 加州迪士尼乐园：有西部风格的建筑和“大雷鸣山铁路”等项目。
#
# 3. **探险世界（Adventureland）**：
#    - 佛罗里达州迪士尼世界：有热带雨林的景观和“丛林探险”等项目。
#    - 巴黎迪士尼乐园：有热带雨林的景观和“丛林探险”等项目。
#    - 中国香港迪士尼乐园：有丛林河流之旅和泰山树屋等冒险元素。
#    - 东京迪士尼乐园：有丛林河流之旅和泰山树屋等冒险元素。
#
# 4. **明日世界（Tomorrowland）**：
#    - 佛罗里达州迪士尼世界：有现代科技的气息，有“太空山”、“星际旅行”等高科技项目。
#    - 巴黎迪士尼乐园：有现代科技的气息，有“太空山”、“星际旅行”等高科技项目。
#    - 中国香港迪士尼乐园：有高科技互动项目。
#    - 东京迪士尼乐园：有高科技互动项目。
#    - 上海迪士尼乐园：有科幻与未来感十足的高科技互动项目。
#
# 5. **米奇卡通城（Mickey's Toontown）**：
#    - 中国香港迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#    - 东京迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#    - 加州迪士尼乐园：以卡通风格为主题，适合家庭游玩。
#
# 6. **新奥尔良广场
